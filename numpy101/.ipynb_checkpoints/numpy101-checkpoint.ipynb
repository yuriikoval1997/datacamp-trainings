# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.array([1, 2, 3])
# Out:
# array([1, 2, 3])

# %%
data = np.array([20.54255679, 20.54255679, 20.69282047, 20.69282047, 20.34343189, 20.34343189, 
 20.69282047, 20.15883472, 19.4984471 , 20.69282047, 20.9205219, 20.54255679, 
 20.54255679, 20.69282047, 20.69282047, 20.34343189, 20.34343189, 20.69282047, 
 20.15883472, 19.4984471, 20.69282047, 20.9205219, 23.11037639, 27.60406069, 28.48080465, 
 25.62295933, 23.74810865, 25.72686361])

# %%
# show elements that are bigger than 21
data[data > 21]
# Out:
# array([23.11037639, 27.60406069, 28.48080465, 25.62295933, 23.74810865,
#        25.72686361])

# %%
# creates boolean array
bool_np = data > 21
bool_np
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False,  True,  True,  True,  True,  True,
#         True])

# %%
bool_np = data > np.array([i for i in range(0, data.shape[0])])
bool_np
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True, False,  True,  True,  True,  True, False,
#        False])

# %%
# but if you need to do and, or, not operation on boolean numpy array, then use functions
# data and np.array([i for i in range(0, data.shape[0])]) #==> not gonna work
np.logical_and(data, np.array([i for i in range(0, data.shape[0])]))
# Out:
# array([False,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True])

# %%
# Create baseball, a list of lists
baseball = [[180, 78.4],
            [215, 102.7],
            [210, 98.5],
            [188, 75.2]]

# Create a 2D numpy array from baseball: np_baseball
np_baseball = np.array(baseball)

# Print out the type of np_baseball
print(type(np_baseball))

# Print out the shape of np_baseball
print(np_baseball.shape)
# Out:
# <class 'numpy.ndarray'>
# (4, 2)

# %%
# Print mean height (first column)
avg = np.mean(np_baseball[:,0])
print("Average: " + str(avg))

# Print median height.
med = np.median(np_baseball[:, 0])
print("Median: " + str(med))

# Print out the standard deviation on height.
stddev = np.std(np_baseball[:, 0])
print("Standard Deviation: " + str(stddev))

# Print out correlation between first and second column.
corr = np.corrcoef(np_baseball[:, 0], np_baseball[:, 1])
print("Correlation: " + str(corr))
# Out:
# Average: 198.25
# Median: 199.0
# Standard Deviation: 14.635146053251399
# Correlation: [[1.         0.95865738]
#  [0.95865738 1.        ]]

# %%
# 'GK' (goalkeeper), 'M' (midfield), 'A' (attack) and 'D' (defense).
positions = ['GK', 'M', 'A', 'D']
heights = [191, 184, 185, 180]

# Convert positions and heights to numpy arrays: np_positions, np_heights
np_positions = np.array(positions)
np_heights = np.array(heights)

# Heights of the goalkeepers: np_heights
gk_heights = np_heights[np_positions == 'GK']

# Heights of the other players: other_heights
other_heights = np_heights[np_positions != 'GK']

# Print out the median height of goalkeepers.
print("Median height of goalkeepers: " + str(np.median(gk_heights)))

# Print out the median height of other players.
print("Median height of other players: " + str(np.median(other_heights)))
# Out:
# Median height of goalkeepers: 191.0
# Median height of other players: 184.0

# %%
# iterate over all of the elements in ndarray
for x in np.nditer(np.array([positions, heights])):
    print(x)
# Out:
# GK
# M
# A
# D
# 191
# 184
# 185
# 180

# %% [markdown]
# ## Import data

# %%
# Use loadtxt when all data is of the same type
digits = np.loadtxt('datasets/mnist_kaggle_some_rows.csv', delimiter=',', dtype=float)
print(type(digits))

# Select and reshape a row
im = digits[21, 1:]
im_sq = np.reshape(im, (28, 28))

plt.imshow(im_sq, cmap='Greys', interpolation='nearest')
plt.show()
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# ### Structured Array

# %% [markdown]
# #### genfromtxt

# %%
titanic = np.genfromtxt('datasets/titanic_sub.csv', delimiter=',', names=True, dtype=None, encoding='ASCII')
display(titanic[:10])
display(type(titanic))
# Out:
# array([( 1, 0, 3, 'male', 22., 1, 0, 'A/5 21171',  7.25  , '', 'S'),
#        ( 2, 1, 1, 'female', 38., 1, 0, 'PC 17599', 71.2833, 'C85', 'C'),
#        ( 3, 1, 3, 'female', 26., 0, 0, 'STON/O2. 3101282',  7.925 , '', 'S'),
#        ( 4, 1, 1, 'female', 35., 1, 0, '113803', 53.1   , 'C123', 'S'),
#        ( 5, 0, 3, 'male', 35., 0, 0, '373450',  8.05  , '', 'S'),
#        ( 6, 0, 3, 'male', nan, 0, 0, '330877',  8.4583, '', 'Q'),
#        ( 7, 0, 1, 'male', 54., 0, 0, '17463', 51.8625, 'E46', 'S'),
#        ( 8, 0, 3, 'male',  2., 3, 1, '349909', 21.075 , '', 'S'),
#        ( 9, 1, 3, 'female', 27., 0, 2, '347742', 11.1333, '', 'S'),
#        (10, 1, 2, 'female', 14., 1, 0, '237736', 30.0708, '', 'C')],
#       dtype=[('PassengerId', '<i8'), ('Survived', '<i8'), ('Pclass', '<i8'), ('Sex', '<U6'), ('Age', '<f8'), ('SibSp', '<i8'), ('Parch', '<i8'), ('Ticket', '<U18'), ('Fare', '<f8'), ('Cabin', '<U15'), ('Embarked', '<U1')])
# numpy.ndarray

# %%
titanic['Survived'][:10]
# Out:
# array([0, 1, 1, 1, 0, 0, 0, 0, 1, 1])

# %% [markdown]
# #### recfromcsv
# * `np.recfromcsv` that behaves similarly to `np.genfromtxt`, except that its default dtype is None.
# * The function recfromcsv invoke genfromtxt with parameters names=True as default. It means that it read the first line of the data as the header.

# %%
d = np.recfromcsv('datasets/titanic_sub.csv', delimiter=',', encoding='ASCII')
d[:10]
# Out:
# rec.array([( 1, 0, 3, 'male', 22., 1, 0, 'A/5 21171',  7.25  , '', 'S'),
#            ( 2, 1, 1, 'female', 38., 1, 0, 'PC 17599', 71.2833, 'C85', 'C'),
#            ( 3, 1, 3, 'female', 26., 0, 0, 'STON/O2. 3101282',  7.925 , '', 'S'),
#            ( 4, 1, 1, 'female', 35., 1, 0, '113803', 53.1   , 'C123', 'S'),
#            ( 5, 0, 3, 'male', 35., 0, 0, '373450',  8.05  , '', 'S'),
#            ( 6, 0, 3, 'male', nan, 0, 0, '330877',  8.4583, '', 'Q'),
#            ( 7, 0, 1, 'male', 54., 0, 0, '17463', 51.8625, 'E46', 'S'),
#            ( 8, 0, 3, 'male',  2., 3, 1, '349909', 21.075 , '', 'S'),
#            ( 9, 1, 3, 'female', 27., 0, 2, '347742', 11.1333, '', 'S'),
#            (10, 1, 2, 'female', 14., 1, 0, '237736', 30.0708, '', 'C')],
#           dtype=[('passengerid', '<i8'), ('survived', '<i8'), ('pclass', '<i8'), ('sex', '<U6'), ('age', '<f8'), ('sibsp', '<i8'), ('parch', '<i8'), ('ticket', '<U18'), ('fare', '<f8'), ('cabin', '<U15'), ('embarked', '<U1')])

# %% [markdown]
# # Hacker statistics

# %%
# Generate a pseudo random number
np.random.rand()
# Out:
# 0.9643850509192133

# %% [markdown]
# When you set seed to a specific numper, that can be used to generate reproduceble sequence of pseudo generated numbers.

# %%
np.random.seed(123)
[np.random.rand() for i in range(3)]
# Out:
# [0.6964691855978616, 0.28613933495037946, 0.2268514535642031]

# %%
np.random.seed(123)
[np.random.rand() for i in range(3)]
# Out:
# [0.6964691855978616, 0.28613933495037946, 0.2268514535642031]

# %%
np.random.seed(42)
print('Simulating coin toss...')
[np.random.randint(0, 2) for i in range(7)]
# Out:
# Simulating coin toss...
# [0, 1, 0, 0, 0, 1, 0]

# %%
# Initialize random_walk
random_walk = [0]

for x in range(100) :
    # Set step: last element in random_walk
    step = random_walk[-1]

    # Roll the dice
    dice = np.random.randint(1,7)

    # Determine next step
    if dice <= 2:
        step = step - 1
    elif dice <= 5:
        step = step + 1
    else:
        step = step + np.random.randint(1,7)

    # append next_step to random_walk
    random_walk.append(step)

# Print random_walk
print(random_walk)
# Out:
# [0, 1, 0, 1, 2, 3, 4, 5, 6, 11, 10, 11, 17, 16, 17, 18, 17, 18, 17, 22, 23, 22, 21, 22, 23, 22, 23, 24, 30, 33, 34, 35, 34, 35, 36, 37, 38, 37, 36, 37, 36, 37, 39, 38, 37, 36, 37, 36, 37, 38, 39, 40, 41, 42, 43, 44, 43, 44, 43, 49, 51, 52, 57, 56, 55, 56, 55, 54, 58, 64, 65, 64, 69, 70, 69, 70, 69, 68, 69, 70, 71, 72, 71, 72, 73, 72, 71, 70, 69, 70, 71, 72, 71, 72, 73, 72, 73, 74, 73, 72, 71]

# %%
import matplotlib.pyplot as plt
plt.plot(random_walk)
plt.show()

# %% [markdown]
# Using generating many random walk

# %%
# initialize and populate all_walks
all_walks = []
for i in range(10) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)
        random_walk.append(step)
    all_walks.append(random_walk)

# Convert all_walks to Numpy array: np_aw
np_aw = np.array(all_walks)
print(np_aw.shape, np_aw, sep='\n')

# Plot np_aw and show
plt.plot(np_aw)
plt.show()

# Clear the figure
plt.clf()

# Transpose np_aw: np_aw_t
np_aw_t = np_aw.transpose()
print(np_aw_t.shape, np_aw_t, sep='\n')

# Plot np_aw_t and show
plt.plot(np_aw_t)
plt.show()
# Out:
# (10, 101)
# [[ 0  1  0 ... 77 76 81]
#  [ 0  1  0 ... 78 79 80]
#  [ 0  5 10 ... 73 72 73]
#  ...
#  [ 0  0  0 ... 92 98 99]
#  [ 0  3  4 ... 84 85 86]
#  [ 0  0  1 ... 68 69 75]]
# (101, 10)
# [[ 0  0  0 ...  0  0  0]
#  [ 1  1  5 ...  0  3  0]
#  [ 0  0 10 ...  0  4  1]
#  ...
#  [77 78 73 ... 92 84 68]
#  [76 79 72 ... 98 85 69]
#  [81 80 73 ... 99 86 75]]
