# %%
from graphviz import Digraph

# %%
d = Digraph(comment='TestCase State Diagram', format='png')

# %%
d.edge('APPROVED', 'AUTOMATED_DEV')
d.edge('READY_FOR_AUTOMATION', 'AUTOMATED_DEV')
d.edge('NEED_TO_REDESIGN_FOR_AUTOMATION', 'AUTOMATED_DEV')
d.edge('MANUAL_EXCECUTION', 'AUTOMATED_DEV')
d.render('./graph.png')
d
